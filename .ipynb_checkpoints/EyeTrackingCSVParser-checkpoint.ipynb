# %% [markdown]
# ### CSV Parser for Eye Time Based Data
#
# The objective of this script is to take a CSV file consisting of eye tracking data and return a metric for the average "processing fluency" of the conducted test. The eye tracking data contained in the file has the following structure: [X Screen Position of Eye Focus, Y Screen Position of Eye Focus, Milliseconds since the beginning of the test]. The processing fluency metric will be derived for each in-order pair of data points by dividing the time (ms) difference between data points by the Euclidean (straight-line in pixels) distance of the data points. The average of these individual derived values will be taken to obtain the final average processing fluency of the test for that particular participant.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Fields in CSV:
# * [tester_id, tester_age, tester_gender, item_id, test_id, test_created_at, test_browser_width_px, test_browser_height_px, test_duration_ms, test_raw_data]

# %%
import csv
import math

test_data_index = 9
count = 0

def Euclidean_Distance(x1, y1, x2, y2):
    diffx = x2-x1
    diffy = y2-y1
    return math.sqrt((diffx**2) + (diffy**2))

def Average_List(lst): 
    return sum(lst) / len(lst)


with open('test.csv', newline='\n') as f:
    reader = csv.reader(f)
    for row in reader:
        if count>0:
            #row[test_data_index] is a string lol
            #print(row[test_data_index])
            stringData = row[test_data_index]
            data_points_raw = stringData[2:len(stringData)-2].split('],[')
            dps_parsed = []
            for dp in data_points_raw:
                dps_parsed.append(dp.split(','))
            Inverse_PF_data = []
            for index in range(0,len(dps_parsed)-1):
                x1 = float(dps_parsed[index][0])
                y1 = float(dps_parsed[index][1])
                x2 = float(dps_parsed[index+1][0])
                y2 = float(dps_parsed[index+1][1])
                print(dps_parsed[index])
                print(dps_parsed[index+1])
                #Distance Formula Tested: WORKING CORRECTLY
                dist = Euclidean_Distance(x1, y1, x2, y2)
                print('Euclidean Distance: ',dist)
                time1 = int(dps_parsed[index][2])
                time2 = int(dps_parsed[index+1][2])
                timeDiff = time2 - time1
                print('Time Difference: ',timeDiff)
                Inverse_PF= dist/timeDiff
                print('Local Inverse Processing Fluency: ',Inverse_PF)
                Inverse_PF_data.append(Inverse_PF)
                print('\n')
            if(len(Inverse_PF_data)>0):
                average = Average_List(Inverse_PF_data)
                print('Average Inverse Processing Fluency for Test: ', average)
                print('Average Processing Fluency for Test', 1/average)
        count+=1
# Out:
# ['51.3', '53.41', '21']
# ['47.45', '47.21', '59']
# Euclidean Distance:  7.298116195293132
# Time Difference:  38
# Local Processing Fluency:  0.19205568934981926
#
#
# ['47.45', '47.21', '59']
# ['43.07', '37.99', '95']
# Euclidean Distance:  10.207487447947218
# Time Difference:  36
# Local Processing Fluency:  0.2835413179985338
#
#
# ['43.07', '37.99', '95']
# ['48.23', '33.57', '115']
# Euclidean Distance:  6.794262285193292
# Time Difference:  20
# Local Processing Fluency:  0.3397131142596646
#
#
# ['48.23', '33.57', '115']
# ['48.96', '32.26', '138']
# Euclidean Distance:  1.4996666296214007
# Time Difference:  23
# Local Processing Fluency:  0.0652028969400609
#
#
# ['48.96', '32.26', '138']
# ['48.96', '32.26', '159']
# Euclidean Distance:  0.0
# Time Difference:  21
# Local Processing Fluency:  0.0
#
#
# ['48.96', '32.26', '159']
# ['49.01', '45.99', '181']
# Euclidean Distance:  13.730091041213095
# Time Difference:  22
# Local Processing Fluency:  0.6240950473278679
#
#
# ['49.01', '45.99', '181']
# ['49.01', '45.99', '200']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['49.01', '45.99', '200']
# ['45.31', '68.27', '220']
# Euclidean Distance:  22.58513670536443
# Time Difference:  20
# Local Processing Fluency:  1.1292568352682215
#
#
# ['45.31', '68.27', '220']
# ['45.68', '43.54', '243']
# Euclidean Distance:  24.732767738366846
# Time Difference:  23
# Local Processing Fluency:  1.0753377277550802
#
#
# ['45.68', '43.54', '243']
# ['41.98', '60.66', '262']
# Euclidean Distance:  17.515261916397364
# Time Difference:  19
# Local Processing Fluency:  0.9218558903367033
#
#
# ['41.98', '60.66', '262']
# ['49.9', '32.26', '285']
# Euclidean Distance:  29.483663273073784
# Time Difference:  23
# Local Processing Fluency:  1.281898403177121
#
#
# ['49.9', '32.26', '285']
# ['46.67', '47.3', '304']
# Euclidean Distance:  15.382928849864708
# Time Difference:  19
# Local Processing Fluency:  0.8096278342034057
#
#
# ['46.67', '47.3', '304']
# ['49.9', '32.26', '322']
# Euclidean Distance:  15.382928849864708
# Time Difference:  18
# Local Processing Fluency:  0.8546071583258171
#
#
# ['49.9', '32.26', '322']
# ['43.85', '53.13', '346']
# Euclidean Distance:  21.729229162581913
# Time Difference:  24
# Local Processing Fluency:  0.905384548440913
#
#
# ['43.85', '53.13', '346']
# ['49.01', '44.1', '372']
# Euclidean Distance:  10.400312495305128
# Time Difference:  26
# Local Processing Fluency:  0.40001201905019723
#
#
# ['49.01', '44.1', '372']
# ['44.95', '42.51', '413']
# Euclidean Distance:  4.360240819037403
# Time Difference:  41
# Local Processing Fluency:  0.10634733704969276
#
#
# ['44.95', '42.51', '413']
# ['39.38', '39.5', '437']
# Euclidean Distance:  6.331271594237606
# Time Difference:  24
# Local Processing Fluency:  0.2638029830932336
#
#
# ['39.38', '39.5', '437']
# ['39.38', '39.5', '455']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['39.38', '39.5', '455']
# ['48.49', '28.49', '479']
# Euclidean Distance:  14.290283412165065
# Time Difference:  24
# Local Processing Fluency:  0.5954284755068777
#
#
# ['48.49', '28.49', '479']
# ['48.49', '28.49', '496']
# Euclidean Distance:  0.0
# Time Difference:  17
# Local Processing Fluency:  0.0
#
#
# ['48.49', '28.49', '496']
# ['48.49', '28.49', '515']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.49', '28.49', '515']
# ['44.95', '43.07', '537']
# Euclidean Distance:  15.00359956810365
# Time Difference:  22
# Local Processing Fluency:  0.6819817985501659
#
#
# ['44.95', '43.07', '537']
# ['44.95', '43.07', '559']
# Euclidean Distance:  0.0
# Time Difference:  22
# Local Processing Fluency:  0.0
#
#
# ['44.95', '43.07', '559']
# ['57.45', '26.71', '581']
# Euclidean Distance:  20.588822210121684
# Time Difference:  22
# Local Processing Fluency:  0.9358555550055311
#
#
# ['57.45', '26.71', '581']
# ['57.45', '26.71', '600']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['57.45', '26.71', '600']
# ['57.45', '26.71', '618']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['57.45', '26.71', '618']
# ['54.53', '31.03', '642']
# Euclidean Distance:  5.214288062621781
# Time Difference:  24
# Local Processing Fluency:  0.2172620026092409
#
#
# ['54.53', '31.03', '642']
# ['54.53', '31.03', '659']
# Euclidean Distance:  0.0
# Time Difference:  17
# Local Processing Fluency:  0.0
#
#
# ['54.53', '31.03', '659']
# ['46.35', '51.91', '682']
# Euclidean Distance:  22.425137680736764
# Time Difference:  23
# Local Processing Fluency:  0.9750059861189897
#
#
# ['46.35', '51.91', '682']
# ['44.38', '74.57', '700']
# Euclidean Distance:  22.74547207687719
# Time Difference:  18
# Local Processing Fluency:  1.2636373376042882
#
#
# ['44.38', '74.57', '700']
# ['44.38', '74.57', '719']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['44.38', '74.57', '719']
# ['38.8', '86.42', '742']
# Euclidean Distance:  13.098049473108592
# Time Difference:  23
# Local Processing Fluency:  0.5694804118742866
#
#
# ['38.8', '86.42', '742']
# ['39.53', '69.97', '760']
# Euclidean Distance:  16.466189601726324
# Time Difference:  18
# Local Processing Fluency:  0.914788311207018
#
#
# ['39.53', '69.97', '760']
# ['21.82', '88.49', '784']
# Euclidean Distance:  25.62488048752618
# Time Difference:  24
# Local Processing Fluency:  1.0677033536469243
#
#
# ['21.82', '88.49', '784']
# ['26.41', '89.9', '802']
# Euclidean Distance:  4.801687203473382
# Time Difference:  18
# Local Processing Fluency:  0.2667604001929657
#
#
# ['26.41', '89.9', '802']
# ['26.41', '89.9', '821']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['26.41', '89.9', '821']
# ['49.53', '29.9', '844']
# Euclidean Distance:  64.30034525568273
# Time Difference:  23
# Local Processing Fluency:  2.795667185029684
#
#
# ['49.53', '29.9', '844']
# ['49.53', '29.9', '863']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['49.53', '29.9', '863']
# ['42.92', '6.3', '885']
# Euclidean Distance:  24.508204748614286
# Time Difference:  22
# Local Processing Fluency:  1.1140093067551948
#
#
# ['42.92', '6.3', '885']
# ['62.03', '12.32', '905']
# Euclidean Distance:  20.035780493906394
# Time Difference:  20
# Local Processing Fluency:  1.0017890246953196
#
#
# ['62.03', '12.32', '905']
# ['47.34', '13.92', '929']
# Euclidean Distance:  14.77687720731278
# Time Difference:  24
# Local Processing Fluency:  0.6157032169713658
#
#
# ['47.34', '13.92', '929']
# ['55.63', '30.66', '947']
# Euclidean Distance:  18.6802489276776
# Time Difference:  18
# Local Processing Fluency:  1.0377916070932
#
#
# ['55.63', '30.66', '947']
# ['55.63', '30.66', '966']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['55.63', '30.66', '966']
# ['43.65', '36.02', '989']
# Euclidean Distance:  13.124404748406693
# Time Difference:  23
# Local Processing Fluency:  0.5706262934089866
#
#
# ['43.65', '36.02', '989']
# ['43.65', '36.02', '1008']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['43.65', '36.02', '1008']
# ['54.74', '57.36', '1030']
# Euclidean Distance:  24.049609144433095
# Time Difference:  22
# Local Processing Fluency:  1.0931640520196861
#
#
# ['54.74', '57.36', '1030']
# ['54.74', '57.36', '1048']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['54.74', '57.36', '1048']
# ['54.74', '57.36', '1068']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['54.74', '57.36', '1068']
# ['38.23', '61.97', '1091']
# Euclidean Distance:  17.14153435372692
# Time Difference:  23
# Local Processing Fluency:  0.7452841023359531
#
#
# ['38.23', '61.97', '1091']
# ['38.23', '61.97', '1111']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['38.23', '61.97', '1111']
# ['49.79', '65.26', '1133']
# Euclidean Distance:  12.01905570334043
# Time Difference:  22
# Local Processing Fluency:  0.5463207137882014
#
#
# ['49.79', '65.26', '1133']
# ['49.79', '65.26', '1153']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['49.79', '65.26', '1153']
# ['49.79', '65.26', '1171']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['49.79', '65.26', '1171']
# ['59.06', '54.64', '1195']
# Euclidean Distance:  14.096712382679875
# Time Difference:  24
# Local Processing Fluency:  0.5873630159449948
#
#
# ['59.06', '54.64', '1195']
# ['59.06', '54.64', '1216']
# Euclidean Distance:  0.0
# Time Difference:  21
# Local Processing Fluency:  0.0
#
#
# ['59.06', '54.64', '1216']
# ['45.63', '62.63', '1239']
# Euclidean Distance:  15.627059864222701
# Time Difference:  23
# Local Processing Fluency:  0.679437385400987
#
#
# ['45.63', '62.63', '1239']
# ['45.63', '62.63', '1258']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['45.63', '62.63', '1258']
# ['48.02', '54.92', '1281']
# Euclidean Distance:  8.071939048332812
# Time Difference:  23
# Local Processing Fluency:  0.350953871666644
#
#
# ['48.02', '54.92', '1281']
# ['48.02', '54.92', '1304']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['48.02', '54.92', '1304']
# ['48.02', '72.13', '1327']
# Euclidean Distance:  17.209999999999994
# Time Difference:  23
# Local Processing Fluency:  0.7482608695652171
#
#
# ['48.02', '72.13', '1327']
# ['48.02', '72.13', '1347']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['48.02', '72.13', '1347']
# ['53.96', '58.49', '1364']
# Euclidean Distance:  14.8772712551731
# Time Difference:  17
# Local Processing Fluency:  0.8751336032454765
#
#
# ['53.96', '58.49', '1364']
# ['52.29', '23.04', '1388']
# Euclidean Distance:  35.48931388460476
# Time Difference:  24
# Local Processing Fluency:  1.4787214118585317
#
#
# ['52.29', '23.04', '1388']
# ['52.29', '23.04', '1406']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['52.29', '23.04', '1406']
# ['53.44', '37.24', '1434']
# Euclidean Distance:  14.246490795982007
# Time Difference:  28
# Local Processing Fluency:  0.5088032427136431
#
#
# ['53.44', '37.24', '1434']
# ['53.44', '37.24', '1454']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['53.44', '37.24', '1454']
# ['53.96', '34.51', '1477']
# Euclidean Distance:  2.779082582436158
# Time Difference:  23
# Local Processing Fluency:  0.12082967749722426
#
#
# ['53.96', '34.51', '1477']
# ['37.97', '72.41', '1499']
# Euclidean Distance:  41.13502279080443
# Time Difference:  22
# Local Processing Fluency:  1.869773763218383
#
#
# ['37.97', '72.41', '1499']
# ['47.6', '71.28', '1523']
# Euclidean Distance:  9.696071369374302
# Time Difference:  24
# Local Processing Fluency:  0.40400297372392924
#
#
# ['47.6', '71.28', '1523']
# ['47.6', '71.28', '1544']
# Euclidean Distance:  0.0
# Time Difference:  21
# Local Processing Fluency:  0.0
#
#
# ['47.6', '71.28', '1544']
# ['44.79', '56.24', '1564']
# Euclidean Distance:  15.300251631917693
# Time Difference:  20
# Local Processing Fluency:  0.7650125815958846
#
#
# ['44.79', '56.24', '1564']
# ['46.15', '54.35', '1587']
# Euclidean Distance:  2.3284544230025204
# Time Difference:  23
# Local Processing Fluency:  0.10123714882619654
#
#
# ['46.15', '54.35', '1587']
# ['46.15', '54.35', '1606']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['46.15', '54.35', '1606']
# ['50.52', '43.63', '1629']
# Euclidean Distance:  11.57649774327279
# Time Difference:  23
# Local Processing Fluency:  0.5033259888379474
#
#
# ['50.52', '43.63', '1629']
# ['50.52', '43.63', '1652']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['50.52', '43.63', '1652']
# ['47.19', '50.03', '1675']
# Euclidean Distance:  7.214492359133803
# Time Difference:  23
# Local Processing Fluency:  0.31367358083190444
#
#
# ['47.19', '50.03', '1675']
# ['46.82', '39.03', '1698']
# Euclidean Distance:  11.006220968161596
# Time Difference:  23
# Local Processing Fluency:  0.4785313464418085
#
#
# ['46.82', '39.03', '1698']
# ['46.82', '39.03', '1717']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['46.82', '39.03', '1717']
# ['47.34', '39.21', '1741']
# Euclidean Distance:  0.5502726596879071
# Time Difference:  24
# Local Processing Fluency:  0.022928027486996128
#
#
# ['47.34', '39.21', '1741']
# ['47.34', '39.21', '1760']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['47.34', '39.21', '1760']
# ['48.28', '32.16', '1784']
# Euclidean Distance:  7.112390596698135
# Time Difference:  24
# Local Processing Fluency:  0.2963496081957556
#
#
# ['48.28', '32.16', '1784']
# ['48.28', '32.16', '1803']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.28', '32.16', '1803']
# ['48.28', '32.16', '1822']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.28', '32.16', '1822']
# ['39.64', '23.98', '1846']
# Euclidean Distance:  11.897983022344583
# Time Difference:  24
# Local Processing Fluency:  0.49574929259769096
#
#
# ['39.64', '23.98', '1846']
# ['39.64', '23.98', '1882']
# Euclidean Distance:  0.0
# Time Difference:  36
# Local Processing Fluency:  0.0
#
#
# ['39.64', '23.98', '1882']
# ['33.8', '30.84', '1906']
# Euclidean Distance:  9.009173103010067
# Time Difference:  24
# Local Processing Fluency:  0.37538221262541943
#
#
# ['33.8', '30.84', '1906']
# ['37.24', '40.53', '1930']
# Euclidean Distance:  10.282494833453603
# Time Difference:  24
# Local Processing Fluency:  0.42843728472723347
#
#
# ['37.24', '40.53', '1930']
# ['37.24', '40.53', '1954']
# Euclidean Distance:  0.0
# Time Difference:  24
# Local Processing Fluency:  0.0
#
#
# ['37.24', '40.53', '1954']
# ['33.18', '29.9', '1977']
# Euclidean Distance:  11.378949863673716
# Time Difference:  23
# Local Processing Fluency:  0.4947369505945094
#
#
# ['33.18', '29.9', '1977']
# ['33.18', '29.9', '1996']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['33.18', '29.9', '1996']
# ['33.18', '29.9', '2016']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['33.18', '29.9', '2016']
# ['29.74', '37.52', '2039']
# Euclidean Distance:  8.360502377249832
# Time Difference:  23
# Local Processing Fluency:  0.3635001033586883
#
#
# ['29.74', '37.52', '2039']
# ['29.74', '37.52', '2058']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['29.74', '37.52', '2058']
# ['23.91', '19.37', '2081']
# Euclidean Distance:  19.063352276029526
# Time Difference:  23
# Local Processing Fluency:  0.8288414033056316
#
#
# ['23.91', '19.37', '2081']
# ['23.91', '19.37', '2100']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['23.91', '19.37', '2100']
# ['23.91', '19.37', '2120']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['23.91', '19.37', '2120']
# ['24.64', '31.6', '2145']
# Euclidean Distance:  12.25176721946675
# Time Difference:  25
# Local Processing Fluency:  0.49007068877867
#
#
# ['24.64', '31.6', '2145']
# ['24.64', '31.6', '2163']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['24.64', '31.6', '2163']
# ['30.78', '61.31', '2187']
# Euclidean Distance:  30.33782622403919
# Time Difference:  24
# Local Processing Fluency:  1.2640760926682997
#
#
# ['30.78', '61.31', '2187']
# ['30.78', '61.31', '2207']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['30.78', '61.31', '2207']
# ['20.47', '75.8', '2230']
# Euclidean Distance:  17.783593562607077
# Time Difference:  23
# Local Processing Fluency:  0.7731997201133511
#
#
# ['20.47', '75.8', '2230']
# ['31.3', '83.13', '2248']
# Euclidean Distance:  13.077377412921905
# Time Difference:  18
# Local Processing Fluency:  0.7265209673845503
#
#
# ['31.3', '83.13', '2248']
# ['23.07', '93.29', '2271']
# Euclidean Distance:  13.075109942176402
# Time Difference:  23
# Local Processing Fluency:  0.5684830409641914
#
#
# ['23.07', '93.29', '2271']
# ['32.92', '89.62', '2294']
# Euclidean Distance:  10.511488952569946
# Time Difference:  23
# Local Processing Fluency:  0.457021258807389
#
#
# ['32.92', '89.62', '2294']
# ['39.17', '87.27', '2314']
# Euclidean Distance:  6.677200011981073
# Time Difference:  20
# Local Processing Fluency:  0.33386000059905363
#
#
# ['39.17', '87.27', '2314']
# ['36.56', '23.89', '2338']
# Euclidean Distance:  63.43371737491032
# Time Difference:  24
# Local Processing Fluency:  2.64307155728793
#
#
# ['36.56', '23.89', '2338']
# ['36.56', '23.89', '2357']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['36.56', '23.89', '2357']
# ['27.55', '8.37', '2381']
# Euclidean Distance:  17.94576551724668
# Time Difference:  24
# Local Processing Fluency:  0.7477402298852783
#
#
# ['27.55', '8.37', '2381']
# ['33.85', '0', '2405']
# Euclidean Distance:  10.476015463906112
# Time Difference:  24
# Local Processing Fluency:  0.4365006443294213
#
#
# ['33.85', '0', '2405']
# ['32.6', '20.41', '2428']
# Euclidean Distance:  20.448241978223948
# Time Difference:  23
# Local Processing Fluency:  0.8890539990532151
#
#
# ['32.6', '20.41', '2428']
# ['28.96', '34.32', '2447']
# Euclidean Distance:  14.378376125279239
# Time Difference:  19
# Local Processing Fluency:  0.7567566381725915
#
#
# ['28.96', '34.32', '2447']
# ['26.09', '51.25', '2470']
# Euclidean Distance:  17.171540408478208
# Time Difference:  23
# Local Processing Fluency:  0.746588713412096
#
#
# ['26.09', '51.25', '2470']
# ['21.15', '50.12', '2493']
# Euclidean Distance:  5.067593117052711
# Time Difference:  23
# Local Processing Fluency:  0.2203301355240309
#
#
# ['21.15', '50.12', '2493']
# ['22.81', '49.65', '2512']
# Euclidean Distance:  1.7252536045462996
# Time Difference:  19
# Local Processing Fluency:  0.0908028212919105
#
#
# ['22.81', '49.65', '2512']
# ['29.95', '47.77', '2535']
# Euclidean Distance:  7.383359668877034
# Time Difference:  23
# Local Processing Fluency:  0.32101563777726233
#
#
# ['29.95', '47.77', '2535']
# ['29.95', '47.77', '2555']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['29.95', '47.77', '2555']
# ['37.34', '43.07', '2577']
# Euclidean Distance:  8.757973509893718
# Time Difference:  22
# Local Processing Fluency:  0.398089704995169
#
#
# ['37.34', '43.07', '2577']
# ['37.34', '43.07', '2597']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['37.34', '43.07', '2597']
# ['37.34', '43.07', '2616']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['37.34', '43.07', '2616']
# ['33.23', '51.53', '2640']
# Euclidean Distance:  9.405514340002894
# Time Difference:  24
# Local Processing Fluency:  0.3918964308334539
#
#
# ['33.23', '51.53', '2640']
# ['33.23', '51.53', '2659']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['33.23', '51.53', '2659']
# ['36.82', '33.29', '2681']
# Euclidean Distance:  18.58993544905415
# Time Difference:  22
# Local Processing Fluency:  0.8449970658660977
#
#
# ['36.82', '33.29', '2681']
# ['36.82', '33.29', '2713']
# Euclidean Distance:  0.0
# Time Difference:  32
# Local Processing Fluency:  0.0
#
#
# ['36.82', '33.29', '2713']
# ['30.21', '25.67', '2736']
# Euclidean Distance:  10.087442688808693
# Time Difference:  23
# Local Processing Fluency:  0.43858446473081275
#
#
# ['30.21', '25.67', '2736']
# ['30.21', '25.67', '2755']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['30.21', '25.67', '2755']
# ['34.9', '24.54', '2777']
# Euclidean Distance:  4.824209779849959
# Time Difference:  22
# Local Processing Fluency:  0.21928226272045268
#
#
# ['34.9', '24.54', '2777']
# ['34.9', '24.54', '2801']
# Euclidean Distance:  0.0
# Time Difference:  24
# Local Processing Fluency:  0.0
#
#
# ['34.9', '24.54', '2801']
# ['22.4', '34.7', '2823']
# Euclidean Distance:  16.108246335340173
# Time Difference:  22
# Local Processing Fluency:  0.7321930152427352
#
#
# ['22.4', '34.7', '2823']
# ['22.4', '34.7', '2843']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['22.4', '34.7', '2843']
# ['22.4', '34.7', '2861']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['22.4', '34.7', '2861']
# ['29.48', '32.44', '2884']
# Euclidean Distance:  7.431958019257109
# Time Difference:  23
# Local Processing Fluency:  0.3231286095329178
#
#
# ['29.48', '32.44', '2884']
# ['29.48', '32.44', '2904']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['29.48', '32.44', '2904']
# ['24.84', '38.65', '2927']
# Euclidean Distance:  7.752012641888557
# Time Difference:  23
# Local Processing Fluency:  0.33704402790819815
#
#
# ['24.84', '38.65', '2927']
# ['24.84', '38.65', '2947']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['24.84', '38.65', '2947']
# ['25.47', '32.54', '2966']
# Euclidean Distance:  6.14239367022336
# Time Difference:  19
# Local Processing Fluency:  0.32328387738017683
#
#
# ['25.47', '32.54', '2966']
# ['21.72', '41.19', '2989']
# Euclidean Distance:  9.427884174086993
# Time Difference:  23
# Local Processing Fluency:  0.4099080075689997
#
#
# ['21.72', '41.19', '2989']
# ['21.72', '41.19', '3007']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['21.72', '41.19', '3007']
# ['29.84', '41.85', '3030']
# Euclidean Distance:  8.146778504415105
# Time Difference:  23
# Local Processing Fluency:  0.3542077610615263
#
#
# ['29.84', '41.85', '3030']
# ['35.1', '27.46', '3049']
# Euclidean Distance:  15.321217314560878
# Time Difference:  19
# Local Processing Fluency:  0.8063798586610988
#
#
# ['35.1', '27.46', '3049']
# ['35.1', '27.46', '3068']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['35.1', '27.46', '3068']
# ['26.61', '27.84', '3092']
# Euclidean Distance:  8.4984998676237
# Time Difference:  24
# Local Processing Fluency:  0.3541041611509875
#
#
# ['26.61', '27.84', '3092']
# ['26.61', '27.84', '3110']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['26.61', '27.84', '3110']
# ['33.02', '17.96', '3134']
# Euclidean Distance:  11.777202554087284
# Time Difference:  24
# Local Processing Fluency:  0.49071677308697015
#
#
# ['33.02', '17.96', '3134']
# ['33.02', '17.96', '3154']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['33.02', '17.96', '3154']
# ['52.08', '32.16', '3178']
# Euclidean Distance:  23.7681215075992
# Time Difference:  24
# Local Processing Fluency:  0.9903383961499667
#
#
# ['52.08', '32.16', '3178']
# ['46.93', '47.02', '3197']
# Euclidean Distance:  15.727113530460706
# Time Difference:  19
# Local Processing Fluency:  0.8277428173926688
#
#
# ['46.93', '47.02', '3197']
# ['50.1', '52.66', '3215']
# Euclidean Distance:  6.469814525935031
# Time Difference:  18
# Local Processing Fluency:  0.35943414032972393
#
#
# ['50.1', '52.66', '3215']
# ['49.17', '39.59', '3237']
# Euclidean Distance:  13.103045447528594
# Time Difference:  22
# Local Processing Fluency:  0.5955929748876634
#
#
# ['49.17', '39.59', '3237']
# ['49.17', '39.59', '3256']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['49.17', '39.59', '3256']
# ['48.59', '26.33', '3279']
# Euclidean Distance:  13.272678704767932
# Time Difference:  23
# Local Processing Fluency:  0.5770729871638232
#
#
# ['48.59', '26.33', '3279']
# ['48.59', '26.33', '3298']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.59', '26.33', '3298']
# ['48.59', '26.33', '3317']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.59', '26.33', '3317']
# ['50.1', '7.43', '3339']
# Euclidean Distance:  18.960224154793107
# Time Difference:  22
# Local Processing Fluency:  0.8618283706724139
#
#
# ['50.1', '7.43', '3339']
# ['50.1', '7.43', '3357']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['50.1', '7.43', '3357']
# ['49.27', '41.75', '3398']
# Euclidean Distance:  34.33003495483219
# Time Difference:  41
# Local Processing Fluency:  0.8373179257276144
#
#
# ['49.27', '41.75', '3398']
# ['54.32', '32.54', '3418']
# Euclidean Distance:  10.503646985690255
# Time Difference:  20
# Local Processing Fluency:  0.5251823492845127
#
#
# ['54.32', '32.54', '3418']
# ['57.4', '29.53', '3442']
# Euclidean Distance:  4.306564756276164
# Time Difference:  24
# Local Processing Fluency:  0.1794401981781735
#
#
# ['57.4', '29.53', '3442']
# ['57.4', '29.53', '3460']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['57.4', '29.53', '3460']
# ['55.89', '19.94', '3484']
# Euclidean Distance:  9.7081512143147
# Time Difference:  24
# Local Processing Fluency:  0.4045063005964458
#
#
# ['55.89', '19.94', '3484']
# ['55.89', '19.94', '3503']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['55.89', '19.94', '3503']
# ['54.95', '16.17', '3527']
# Euclidean Distance:  3.885421470059586
# Time Difference:  24
# Local Processing Fluency:  0.16189256125248275
#
#
# ['54.95', '16.17', '3527']
# ['54.95', '16.17', '3550']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['54.95', '16.17', '3550']
# ['54.06', '16.93', '3575']
# Euclidean Distance:  1.1703418304068252
# Time Difference:  25
# Local Processing Fluency:  0.04681367321627301
#
#
# ['54.06', '16.93', '3575']
# ['54.06', '16.93', '3594']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['54.06', '16.93', '3594']
# ['54.06', '16.93', '3614']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['54.06', '16.93', '3614']
# ['61.25', '33.95', '3637']
# Euclidean Distance:  18.476376809320602
# Time Difference:  23
# Local Processing Fluency:  0.8033207308400262
#
#
# ['61.25', '33.95', '3637']
# ['61.25', '33.95', '3657']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['61.25', '33.95', '3657']
# ['18.07', '54.54', '3681']
# Euclidean Distance:  47.83785634829387
# Time Difference:  24
# Local Processing Fluency:  1.9932440145122445
#
#
# ['18.07', '54.54', '3681']
# ['31.56', '56.24', '3703']
# Euclidean Distance:  13.596694451226004
# Time Difference:  22
# Local Processing Fluency:  0.6180315659648183
#
#
# ['31.56', '56.24', '3703']
# ['30.68', '75.42', '3725']
# Euclidean Distance:  19.200177082516714
# Time Difference:  22
# Local Processing Fluency:  0.8727353219325779
#
#
# ['30.68', '75.42', '3725']
# ['42.55', '89.34', '3745']
# Euclidean Distance:  18.293804962336292
# Time Difference:  20
# Local Processing Fluency:  0.9146902481168147
#
#
# ['42.55', '89.34', '3745']
# ['45.78', '87.74', '3764']
# Euclidean Distance:  3.6045665481441804
# Time Difference:  19
# Local Processing Fluency:  0.1897140288496937
#
#
# ['45.78', '87.74', '3764']
# ['54.58', '21.72', '3786']
# Euclidean Distance:  66.60390679231962
# Time Difference:  22
# Local Processing Fluency:  3.027450308741801
#
#
# ['54.58', '21.72', '3786']
# ['54.58', '21.72', '3806']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['54.58', '21.72', '3806']
# ['36.56', '9.69', '3829']
# Euclidean Distance:  21.666594102442584
# Time Difference:  23
# Local Processing Fluency:  0.9420258305409819
#
#
# ['36.56', '9.69', '3829']
# ['47.5', '31.32', '3849']
# Euclidean Distance:  24.23923472389341
# Time Difference:  20
# Local Processing Fluency:  1.2119617361946706
#
#
# ['47.5', '31.32', '3849']
# ['46.25', '12.23', '3872']
# Euclidean Distance:  19.13088079519602
# Time Difference:  23
# Local Processing Fluency:  0.8317774258780879
#
#
# ['46.25', '12.23', '3872']
# ['49.9', '31.41', '3891']
# Euclidean Distance:  19.524213172366256
# Time Difference:  19
# Local Processing Fluency:  1.027590166966645
#
#
# ['49.9', '31.41', '3891']
# ['59.32', '51.63', '3910']
# Euclidean Distance:  22.306608886157484
# Time Difference:  19
# Local Processing Fluency:  1.1740320466398675
#
#
# ['59.32', '51.63', '3910']
# ['55.05', '58.49', '3934']
# Euclidean Distance:  8.080377466430638
# Time Difference:  24
# Local Processing Fluency:  0.33668239443460996
#
#
# ['55.05', '58.49', '3934']
# ['57.19', '48.71', '3952']
# Euclidean Distance:  10.011393509397182
# Time Difference:  18
# Local Processing Fluency:  0.5561885282998434
#
#
# ['57.19', '48.71', '3952']
# ['57.19', '48.71', '3972']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['57.19', '48.71', '3972']
# ['58.59', '23.6', '3997']
# Euclidean Distance:  25.14899799196779
# Time Difference:  25
# Local Processing Fluency:  1.0059599196787117
#
#
# ['58.59', '23.6', '3997']
# ['58.59', '23.6', '4017']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['58.59', '23.6', '4017']
# ['47.6', '32.73', '4041']
# Euclidean Distance:  14.287652011439807
# Time Difference:  24
# Local Processing Fluency:  0.595318833809992
#
#
# ['47.6', '32.73', '4041']
# ['47.6', '32.73', '4061']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['47.6', '32.73', '4061']
# ['26.56', '30.56', '4084']
# Euclidean Distance:  21.151607503922722
# Time Difference:  23
# Local Processing Fluency:  0.9196351088662054
#
#
# ['26.56', '30.56', '4084']
# ['26.56', '30.56', '4103']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['26.56', '30.56', '4103']
# ['24.64', '38.65', '4126']
# Euclidean Distance:  8.314715870070366
# Time Difference:  23
# Local Processing Fluency:  0.3615093856552333
#
#
# ['24.64', '38.65', '4126']
# ['24.64', '38.65', '4146']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['24.64', '38.65', '4146']
# ['24.64', '38.65', '4165']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['24.64', '38.65', '4165']
# ['27.29', '33.29', '4188']
# Euclidean Distance:  5.979305979793975
# Time Difference:  23
# Local Processing Fluency:  0.2599698252084337
#
#
# ['27.29', '33.29', '4188']
# ['29.27', '32.26', '4205']
# Euclidean Distance:  2.231882613400625
# Time Difference:  17
# Local Processing Fluency:  0.13128721255297796
#
#
# ['29.27', '32.26', '4205']
# ['23.7', '52.57', '4229']
# Euclidean Distance:  21.059938271514476
# Time Difference:  24
# Local Processing Fluency:  0.8774974279797698
#
#
# ['23.7', '52.57', '4229']
# ['23.7', '52.57', '4251']
# Euclidean Distance:  0.0
# Time Difference:  22
# Local Processing Fluency:  0.0
#
#
# ['23.7', '52.57', '4251']
# ['20.78', '62.44', '4275']
# Euclidean Distance:  10.292876177240254
# Time Difference:  24
# Local Processing Fluency:  0.42886984071834394
#
#
# ['20.78', '62.44', '4275']
# ['20.78', '62.44', '4295']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['20.78', '62.44', '4295']
# ['20.78', '62.44', '4314']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['20.78', '62.44', '4314']
# ['16.51', '68.18', '4339']
# Euclidean Distance:  7.154054794310714
# Time Difference:  25
# Local Processing Fluency:  0.2861621917724285
#
#
# ['16.51', '68.18', '4339']
# ['16.51', '68.18', '4357']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['16.51', '68.18', '4357']
# ['20.21', '63.29', '4380']
# Euclidean Distance:  6.1320551204306755
# Time Difference:  23
# Local Processing Fluency:  0.26661109219263807
#
#
# ['20.21', '63.29', '4380']
# ['20.21', '63.29', '4398']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['20.21', '63.29', '4398']
# ['20.21', '63.29', '4417']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['20.21', '63.29', '4417']
# ['22.29', '88.77', '4450']
# Euclidean Distance:  25.564756990826254
# Time Difference:  33
# Local Processing Fluency:  0.7746896057826138
#
#
# ['22.29', '88.77', '4450']
# ['17.24', '61.13', '4473']
# Euclidean Distance:  28.097546156203745
# Time Difference:  23
# Local Processing Fluency:  1.2216324415740758
#
#
# ['17.24', '61.13', '4473']
# ['17.24', '61.13', '4492']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['17.24', '61.13', '4492']
# ['17.76', '39.68', '4511']
# Euclidean Distance:  21.456302104509998
# Time Difference:  19
# Local Processing Fluency:  1.129279058132105
#
#
# ['17.76', '39.68', '4511']
# ['19.27', '77.86', '4536']
# Euclidean Distance:  38.20984820697407
# Time Difference:  25
# Local Processing Fluency:  1.528393928278963
#
#
# ['19.27', '77.86', '4536']
# ['19.27', '77.86', '4555']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['19.27', '77.86', '4555']
# ['21.61', '62.72', '4577']
# Euclidean Distance:  15.31976501125262
# Time Difference:  22
# Local Processing Fluency:  0.6963529550569373
#
#
# ['21.61', '62.72', '4577']
# ['21.61', '62.72', '4601']
# Euclidean Distance:  0.0
# Time Difference:  24
# Local Processing Fluency:  0.0
#
#
# ['21.61', '62.72', '4601']
# ['21.51', '65.92', '4625']
# Euclidean Distance:  3.201562118716427
# Time Difference:  24
# Local Processing Fluency:  0.13339842161318446
#
#
# ['21.51', '65.92', '4625']
# ['21.51', '65.92', '4648']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['21.51', '65.92', '4648']
# ['21.51', '65.92', '4666']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['21.51', '65.92', '4666']
# ['13.02', '43.16', '4689']
# Euclidean Distance:  24.291926642405297
# Time Difference:  23
# Local Processing Fluency:  1.056170723582839
#
#
# ['13.02', '43.16', '4689']
# ['13.02', '43.16', '4710']
# Euclidean Distance:  0.0
# Time Difference:  21
# Local Processing Fluency:  0.0
#
#
# ['13.02', '43.16', '4710']
# ['18.28', '61.22', '4734']
# Euclidean Distance:  18.810401377961078
# Time Difference:  24
# Local Processing Fluency:  0.7837667240817116
#
#
# ['18.28', '61.22', '4734']
# ['18.28', '61.22', '4753']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['18.28', '61.22', '4753']
# ['23.85', '57.83', '4776']
# Euclidean Distance:  6.520506115325712
# Time Difference:  23
# Local Processing Fluency:  0.2835002658837266
#
#
# ['23.85', '57.83', '4776']
# ['20.63', '55.86', '4801']
# Euclidean Distance:  3.7748244992317206
# Time Difference:  25
# Local Processing Fluency:  0.15099297996926883
#
#
# ['20.63', '55.86', '4801']
# ['39.69', '69.59', '4824']
# Euclidean Distance:  23.49034908212307
# Time Difference:  23
# Local Processing Fluency:  1.0213195253096987
#
#
# ['39.69', '69.59', '4824']
# ['39.69', '69.59', '4842']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['39.69', '69.59', '4842']
# ['47.29', '61.41', '4861']
# Euclidean Distance:  11.165679558360974
# Time Difference:  19
# Local Processing Fluency:  0.5876673451768933
#
#
# ['47.29', '61.41', '4861']
# ['43.85', '58.4', '4885']
# Euclidean Distance:  4.5709626994758965
# Time Difference:  24
# Local Processing Fluency:  0.19045677914482903
#
#
# ['43.85', '58.4', '4885']
# ['43.85', '58.4', '4911']
# Euclidean Distance:  0.0
# Time Difference:  26
# Local Processing Fluency:  0.0
#
#
# ['43.85', '58.4', '4911']
# ['40.99', '58.59', '4957']
# Euclidean Distance:  2.8663042406555514
# Time Difference:  46
# Local Processing Fluency:  0.06231096175338156
#
#
# ['40.99', '58.59', '4957']
# ['46.67', '56.05', '4981']
# Euclidean Distance:  6.222057537503172
# Time Difference:  24
# Local Processing Fluency:  0.2592523973959655
#
#
# ['46.67', '56.05', '4981']
# ['46.67', '56.05', '5000']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['46.67', '56.05', '5000']
# ['46.67', '56.05', '5018']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['46.67', '56.05', '5018']
# ['50.99', '35.26', '5041']
# Euclidean Distance:  21.2340881603143
# Time Difference:  23
# Local Processing Fluency:  0.9232212243614913
#
#
# ['50.99', '35.26', '5041']
# ['41.98', '47.02', '5060']
# Euclidean Distance:  14.814779782365994
# Time Difference:  19
# Local Processing Fluency:  0.7797252517034734
#
#
# ['41.98', '47.02', '5060']
# ['43.59', '46.83', '5083']
# Euclidean Distance:  1.621172415260025
# Time Difference:  23
# Local Processing Fluency:  0.07048575718521848
#
#
# ['43.59', '46.83', '5083']
# ['43.59', '46.83', '5104']
# Euclidean Distance:  0.0
# Time Difference:  21
# Local Processing Fluency:  0.0
#
#
# ['43.59', '46.83', '5104']
# ['41.56', '37.05', '5127']
# Euclidean Distance:  9.988458339503651
# Time Difference:  23
# Local Processing Fluency:  0.43428079736972397
#
#
# ['41.56', '37.05', '5127']
# ['42.86', '56.71', '5147']
# Euclidean Distance:  19.702933791697117
# Time Difference:  20
# Local Processing Fluency:  0.9851466895848559
#
#
# ['42.86', '56.71', '5147']
# ['47.97', '14.48', '5170']
# Euclidean Distance:  42.53804179790133
# Time Difference:  23
# Local Processing Fluency:  1.849480078169623
#
#
# ['47.97', '14.48', '5170']
# ['43.85', '49.84', '5189']
# Euclidean Distance:  35.59921347445755
# Time Difference:  19
# Local Processing Fluency:  1.8736428144451343
#
#
# ['43.85', '49.84', '5189']
# ['47.97', '14.48', '5208']
# Euclidean Distance:  35.59921347445755
# Time Difference:  19
# Local Processing Fluency:  1.8736428144451343
#
#
# ['47.97', '14.48', '5208']
# ['48.8', '54.26', '5231']
# Euclidean Distance:  39.788657931626695
# Time Difference:  23
# Local Processing Fluency:  1.7299416492011606
#
#
# ['48.8', '54.26', '5231']
# ['49.22', '33.01', '5250']
# Euclidean Distance:  21.254150182964267
# Time Difference:  19
# Local Processing Fluency:  1.1186394833139088
#
#
# ['49.22', '33.01', '5250']
# ['47.92', '27.08', '5271']
# Euclidean Distance:  6.070823667345312
# Time Difference:  21
# Local Processing Fluency:  0.2890868413021577
#
#
# ['47.92', '27.08', '5271']
# ['47.92', '27.08', '5290']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['47.92', '27.08', '5290']
# ['47.92', '27.08', '5309']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['47.92', '27.08', '5309']
# ['41.51', '42.69', '5333']
# Euclidean Distance:  16.874839258493694
# Time Difference:  24
# Local Processing Fluency:  0.7031183024372373
#
#
# ['41.51', '42.69', '5333']
# ['41.51', '42.69', '5352']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['41.51', '42.69', '5352']
# ['40.42', '40.63', '5376']
# Euclidean Distance:  2.3306007809146494
# Time Difference:  24
# Local Processing Fluency:  0.09710836587144372
#
#
# ['40.42', '40.63', '5376']
# ['40.42', '40.63', '5394']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['40.42', '40.63', '5394']
# ['40.42', '40.63', '5413']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['40.42', '40.63', '5413']
# ['46.61', '46.27', '5435']
# Euclidean Distance:  8.374108907818192
# Time Difference:  22
# Local Processing Fluency:  0.380641313991736
#
#
# ['46.61', '46.27', '5435']
# ['48.07', '39.21', '5454']
# Euclidean Distance:  7.209382775245051
# Time Difference:  19
# Local Processing Fluency:  0.37944119869710796
#
#
# ['48.07', '39.21', '5454']
# ['41.3', '51.16', '5477']
# Euclidean Distance:  13.734460309746428
# Time Difference:  23
# Local Processing Fluency:  0.5971504482498446
#
#
# ['41.3', '51.16', '5477']
# ['41.3', '51.16', '5497']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['41.3', '51.16', '5497']
# ['41.3', '51.16', '5520']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['41.3', '51.16', '5520']
# ['47.4', '48.71', '5547']
# Euclidean Distance:  6.573621528503143
# Time Difference:  27
# Local Processing Fluency:  0.24346746401863492
#
#
# ['47.4', '48.71', '5547']
# ['47.4', '48.71', '5566']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['47.4', '48.71', '5566']
# ['48.28', '42.6', '5590']
# Euclidean Distance:  6.173046249624249
# Time Difference:  24
# Local Processing Fluency:  0.25721026040101036
#
#
# ['48.28', '42.6', '5590']
# ['48.28', '42.6', '5609']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.28', '42.6', '5609']
# ['50.36', '49.18', '5632']
# Euclidean Distance:  6.900927473897981
# Time Difference:  23
# Local Processing Fluency:  0.3000403249520861
#
#
# ['50.36', '49.18', '5632']
# ['50.36', '49.18', '5652']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['50.36', '49.18', '5652']
# ['44.22', '55.2', '5674']
# Euclidean Distance:  8.598837130682266
# Time Difference:  22
# Local Processing Fluency:  0.3908562332128303
#
#
# ['44.22', '55.2', '5674']
# ['44.22', '55.2', '5694']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['44.22', '55.2', '5694']
# ['44.22', '55.2', '5713']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['44.22', '55.2', '5713']
# ['44.22', '90.75', '5734']
# Euclidean Distance:  35.55
# Time Difference:  21
# Local Processing Fluency:  1.6928571428571426
#
#
# ['44.22', '90.75', '5734']
# ['54.64', '59.15', '5758']
# Euclidean Distance:  33.273659251726436
# Time Difference:  24
# Local Processing Fluency:  1.3864024688219347
#
#
# ['54.64', '59.15', '5758']
# ['40.26', '60.94', '5781']
# Euclidean Distance:  14.490979953060457
# Time Difference:  23
# Local Processing Fluency:  0.6300426066548025
#
#
# ['40.26', '60.94', '5781']
# ['40.83', '71.28', '5801']
# Euclidean Distance:  10.355698914124535
# Time Difference:  20
# Local Processing Fluency:  0.5177849457062267
#
#
# ['40.83', '71.28', '5801']
# ['45.63', '83.32', '5824']
# Euclidean Distance:  12.961543118008745
# Time Difference:  23
# Local Processing Fluency:  0.563545352956902
#
#
# ['45.63', '83.32', '5824']
# ['46.72', '78.43', '5847']
# Euclidean Distance:  5.010009980029966
# Time Difference:  23
# Local Processing Fluency:  0.21782652087086807
#
#
# ['46.72', '78.43', '5847']
# ['50.31', '36.02', '5872']
# Euclidean Distance:  42.56167524898427
# Time Difference:  25
# Local Processing Fluency:  1.7024670099593708
#
#
# ['50.31', '36.02', '5872']
# ['50.31', '36.02', '5891']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['50.31', '36.02', '5891']
# ['53.75', '66.02', '5910']
# Euclidean Distance:  30.196582588100917
# Time Difference:  19
# Local Processing Fluency:  1.589293820426364
#
#
# ['53.75', '66.02', '5910']
# ['38.85', '36.49', '5933']
# Euclidean Distance:  33.07613792449172
# Time Difference:  23
# Local Processing Fluency:  1.4380929532387703
#
#
# ['38.85', '36.49', '5933']
# ['58.85', '49.84', '5952']
# Euclidean Distance:  24.04625750506719
# Time Difference:  19
# Local Processing Fluency:  1.2655925002666941
#
#
# ['58.85', '49.84', '5952']
# ['50.52', '49.93', '5974']
# Euclidean Distance:  8.330486180289839
# Time Difference:  22
# Local Processing Fluency:  0.37865846274044723
#
#
# ['50.52', '49.93', '5974']
# ['63.59', '45.7', '5998']
# Euclidean Distance:  13.737459736064743
# Time Difference:  24
# Local Processing Fluency:  0.5723941556693642
#
#
# ['63.59', '45.7', '5998']
# ['61.2', '28.59', '6022']
# Euclidean Distance:  17.27611646175147
# Time Difference:  24
# Local Processing Fluency:  0.7198381859063113
#
#
# ['61.2', '28.59', '6022']
# ['61.2', '28.59', '6045']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['61.2', '28.59', '6045']
# ['61.2', '28.59', '6062']
# Euclidean Distance:  0.0
# Time Difference:  17
# Local Processing Fluency:  0.0
#
#
# ['61.2', '28.59', '6062']
# ['51.2', '67.8', '6086']
# Euclidean Distance:  40.465097306197094
# Time Difference:  24
# Local Processing Fluency:  1.6860457210915456
#
#
# ['51.2', '67.8', '6086']
# ['51.2', '67.8', '6118']
# Euclidean Distance:  0.0
# Time Difference:  32
# Local Processing Fluency:  0.0
#
#
# ['51.2', '67.8', '6118']
# ['56.98', '62.54', '6141']
# Euclidean Distance:  7.81511356283451
# Time Difference:  23
# Local Processing Fluency:  0.3397875462101961
#
#
# ['56.98', '62.54', '6141']
# ['56.98', '62.54', '6164']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['56.98', '62.54', '6164']
# ['51.93', '43.63', '6187']
# Euclidean Distance:  19.572700375778503
# Time Difference:  23
# Local Processing Fluency:  0.8509869728599349
#
#
# ['51.93', '43.63', '6187']
# ['51.93', '43.63', '6206']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['51.93', '43.63', '6206']
# ['46.41', '56.05', '6229']
# Euclidean Distance:  13.591423766478622
# Time Difference:  23
# Local Processing Fluency:  0.5909314681077662
#
#
# ['46.41', '56.05', '6229']
# ['46.41', '56.05', '6247']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['46.41', '56.05', '6247']
# ['48.96', '69.4', '6271']
# Euclidean Distance:  13.591357548089162
# Time Difference:  24
# Local Processing Fluency:  0.5663065645037151
#
#
# ['48.96', '69.4', '6271']
# ['48.96', '69.4', '6294']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['48.96', '69.4', '6294']
# ['48.96', '69.4', '6313']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.96', '69.4', '6313']
# ['46.51', '70.44', '6335']
# Euclidean Distance:  2.66159726480172
# Time Difference:  22
# Local Processing Fluency:  0.12098169385462364
#
#
# ['46.51', '70.44', '6335']
# ['46.51', '70.44', '6355']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['46.51', '70.44', '6355']
# ['41.72', '76.08', '6378']
# Euclidean Distance:  7.399574312080391
# Time Difference:  23
# Local Processing Fluency:  0.3217206222643648
#
#
# ['41.72', '76.08', '6378']
# ['41.72', '76.08', '6396']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['41.72', '76.08', '6396']
# ['41.72', '76.08', '6414']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['41.72', '76.08', '6414']
# ['36.67', '77.96', '6452']
# Euclidean Distance:  5.388589796969144
# Time Difference:  38
# Local Processing Fluency:  0.14180499465708274
#
#
# ['36.67', '77.96', '6452']
# ['36.67', '77.96', '6471']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['36.67', '77.96', '6471']
# ['37.14', '86.23', '6495']
# Euclidean Distance:  8.283344735069292
# Time Difference:  24
# Local Processing Fluency:  0.3451393639612205
#
#
# ['37.14', '86.23', '6495']
# ['35.73', '82.94', '6513']
# Euclidean Distance:  3.579413359756044
# Time Difference:  18
# Local Processing Fluency:  0.19885629776422464
#
#
# ['35.73', '82.94', '6513']
# ['30.36', '82.38', '6536']
# Euclidean Distance:  5.399120298715335
# Time Difference:  23
# Local Processing Fluency:  0.23474436081371022
#
#
# ['30.36', '82.38', '6536']
# ['30.36', '82.38', '6555']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['30.36', '82.38', '6555']
# ['30.57', '78.99', '6578']
# Euclidean Distance:  3.396498196672568
# Time Difference:  23
# Local Processing Fluency:  0.14767383463793773
#
#
# ['30.57', '78.99', '6578']
# ['30.57', '78.99', '6598']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['30.57', '78.99', '6598']
# ['35.73', '90.84', '6622']
# Euclidean Distance:  12.924708894207257
# Time Difference:  24
# Local Processing Fluency:  0.5385295372586357
#
#
# ['35.73', '90.84', '6622']
# ['35.73', '90.84', '6645']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['35.73', '90.84', '6645']
# ['35.73', '90.84', '6665']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['35.73', '90.84', '6665']
# ['34.17', '91.97', '6688']
# Euclidean Distance:  1.9262658175859257
# Time Difference:  23
# Local Processing Fluency:  0.0837506877211272
#
#
# ['34.17', '91.97', '6688']
# ['34.17', '91.97', '6707']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['34.17', '91.97', '6707']
# ['43.07', '96.39', '6729']
# Euclidean Distance:  9.937122319867054
# Time Difference:  22
# Local Processing Fluency:  0.4516873781757752
#
#
# ['43.07', '96.39', '6729']
# ['43.07', '96.39', '6749']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['43.07', '96.39', '6749']
# ['43.07', '96.39', '6768']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['43.07', '96.39', '6768']
# ['41.61', '86.99', '6790']
# Euclidean Distance:  9.512707290776907
# Time Difference:  22
# Local Processing Fluency:  0.43239578594440486
#
#
# ['41.61', '86.99', '6790']
# ['43.8', '90', '6809']
# Euclidean Distance:  3.7223917042675696
# Time Difference:  19
# Local Processing Fluency:  0.19591535285618789
#
#
# ['43.8', '90', '6809']
# ['42.29', '89.53', '6831']
# Euclidean Distance:  1.5814550262337506
# Time Difference:  22
# Local Processing Fluency:  0.07188431937426139
#
#
# ['42.29', '89.53', '6831']
# ['42.29', '89.53', '6849']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['42.29', '89.53', '6849']
# ['42.29', '89.53', '6867']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['42.29', '89.53', '6867']
# ['38.91', '79.28', '6891']
# Euclidean Distance:  10.792909709619552
# Time Difference:  24
# Local Processing Fluency:  0.44970457123414803
#
#
# ['38.91', '79.28', '6891']
# ['38.91', '79.28', '6909']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['38.91', '79.28', '6909']
# ['41.09', '76.27', '6931']
# Euclidean Distance:  3.7165171868296345
# Time Difference:  22
# Local Processing Fluency:  0.16893259940134703
#
#
# ['41.09', '76.27', '6931']
# ['44.74', '52.94', '6949']
# Euclidean Distance:  23.61379681457431
# Time Difference:  18
# Local Processing Fluency:  1.311877600809684
#
#
# ['44.74', '52.94', '6949']
# ['24.48', '79.18', '6972']
# Euclidean Distance:  33.15124733701585
# Time Difference:  23
# Local Processing Fluency:  1.4413585798702544
#
#
# ...
#
#
# ['36.35', '40.34', '28033']
# ['32.29', '47.11', '28057']
# Euclidean Distance:  7.8940800603996895
# Time Difference:  24
# Local Processing Fluency:  0.3289200025166537
#
#
# ['32.29', '47.11', '28057']
# ['32.29', '47.11', '28076']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['32.29', '47.11', '28076']
# ['32.29', '47.11', '28095']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['32.29', '47.11', '28095']
# ['29.84', '60.84', '28118']
# Euclidean Distance:  13.946877786802325
# Time Difference:  23
# Local Processing Fluency:  0.6063859907305359
#
#
# ['29.84', '60.84', '28118']
# ['29.84', '60.84', '28137']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['29.84', '60.84', '28137']
# ['27.86', '74.95', '28161']
# Euclidean Distance:  14.248245506026347
# Time Difference:  24
# Local Processing Fluency:  0.5936768960844311
#
#
# ['27.86', '74.95', '28161']
# ['12.45', '81.91', '28180']
# Euclidean Distance:  16.908864539051695
# Time Difference:  19
# Local Processing Fluency:  0.8899402388974577
#
#
# ['12.45', '81.91', '28180']
# ['17.86', '73.35', '28203']
# Euclidean Distance:  10.12628757245221
# Time Difference:  23
# Local Processing Fluency:  0.44027337271531347
#
#
# ['17.86', '73.35', '28203']
# ['17.86', '73.35', '28225']
# Euclidean Distance:  0.0
# Time Difference:  22
# Local Processing Fluency:  0.0
#
#
# ['17.86', '73.35', '28225']
# ['17.86', '73.35', '28244']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['17.86', '73.35', '28244']
# ['14.95', '72.03', '28267']
# Euclidean Distance:  3.195387300469222
# Time Difference:  23
# Local Processing Fluency:  0.1389298826290966
#
#
# ['14.95', '72.03', '28267']
# ['14.95', '72.03', '28288']
# Euclidean Distance:  0.0
# Time Difference:  21
# Local Processing Fluency:  0.0
#
#
# ['14.95', '72.03', '28288']
# ['19.06', '69.31', '28310']
# Euclidean Distance:  4.928539337369641
# Time Difference:  22
# Local Processing Fluency:  0.2240245153349837
#
#
# ['19.06', '69.31', '28310']
# ['19.06', '69.31', '28328']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['19.06', '69.31', '28328']
# ['19.06', '69.31', '28359']
# Euclidean Distance:  0.0
# Time Difference:  31
# Local Processing Fluency:  0.0
#
#
# ['19.06', '69.31', '28359']
# ['17.6', '61.5', '28383']
# Euclidean Distance:  7.945294204747866
# Time Difference:  24
# Local Processing Fluency:  0.3310539251978278
#
#
# ['17.6', '61.5', '28383']
# ['24.32', '62.07', '28405']
# Euclidean Distance:  6.74413078165007
# Time Difference:  22
# Local Processing Fluency:  0.3065513991659123
#
#
# ['24.32', '62.07', '28405']
# ['24.32', '62.07', '28424']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['24.32', '62.07', '28424']
# ['24.32', '62.07', '28444']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['24.32', '62.07', '28444']
# ['17.55', '58.02', '28466']
# Euclidean Distance:  7.888941627366751
# Time Difference:  22
# Local Processing Fluency:  0.3585882557893978
#
#
# ['17.55', '58.02', '28466']
# ['17.55', '58.02', '28485']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['17.55', '58.02', '28485']
# ['21.98', '63.01', '28507']
# Euclidean Distance:  6.672705598181292
# Time Difference:  22
# Local Processing Fluency:  0.30330479991733145
#
#
# ['21.98', '63.01', '28507']
# ['21.98', '63.01', '28527']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['21.98', '63.01', '28527']
# ['21.98', '63.01', '28544']
# Euclidean Distance:  0.0
# Time Difference:  17
# Local Processing Fluency:  0.0
#
#
# ['21.98', '63.01', '28544']
# ['17.92', '61.13', '28566']
# Euclidean Distance:  4.474147963579208
# Time Difference:  22
# Local Processing Fluency:  0.20337036198087308
#
#
# ['17.92', '61.13', '28566']
# ['17.92', '61.13', '28586']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['17.92', '61.13', '28586']
# ['16.25', '47.02', '28610']
# Euclidean Distance:  14.208483381416892
# Time Difference:  24
# Local Processing Fluency:  0.5920201408923705
#
#
# ['16.25', '47.02', '28610']
# ['16.25', '47.02', '28629']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['16.25', '47.02', '28629']
# ['16.61', '55.48', '28652']
# Euclidean Distance:  8.467656110164128
# Time Difference:  23
# Local Processing Fluency:  0.36815896131148385
#
#
# ['16.61', '55.48', '28652']
# ['16.61', '55.48', '28675']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['16.61', '55.48', '28675']
# ['17.29', '42.88', '28695']
# Euclidean Distance:  12.618335864922912
# Time Difference:  20
# Local Processing Fluency:  0.6309167932461456
#
#
# ['17.29', '42.88', '28695']
# ['11.93', '40.91', '28717']
# Euclidean Distance:  5.710560392816104
# Time Difference:  22
# Local Processing Fluency:  0.25957092694618655
#
#
# ['11.93', '40.91', '28717']
# ['11.93', '40.91', '28735']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['11.93', '40.91', '28735']
# ['11.15', '52.76', '28757']
# Euclidean Distance:  11.875643140478752
# Time Difference:  22
# Local Processing Fluency:  0.5398019609308524
#
#
# ['11.15', '52.76', '28757']
# ['11.15', '52.76', '28776']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['11.15', '52.76', '28776']
# ['11.15', '52.76', '28795']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['11.15', '52.76', '28795']
# ['13.59', '52.29', '28819']
# Euclidean Distance:  2.4848541204666312
# Time Difference:  24
# Local Processing Fluency:  0.1035355883527763
#
#
# ['13.59', '52.29', '28819']
# ['13.59', '52.29', '28837']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['13.59', '52.29', '28837']
# ['14.69', '55.01', '28860']
# Euclidean Distance:  2.934007498286259
# Time Difference:  23
# Local Processing Fluency:  0.1275655434037504
#
#
# ['14.69', '55.01', '28860']
# ['14.69', '55.01', '28884']
# Euclidean Distance:  0.0
# Time Difference:  24
# Local Processing Fluency:  0.0
#
#
# ['14.69', '55.01', '28884']
# ['15.42', '54.82', '28908']
# Euclidean Distance:  0.7543208866258442
# Time Difference:  24
# Local Processing Fluency:  0.03143003694274351
#
#
# ['15.42', '54.82', '28908']
# ['15.42', '54.82', '28927']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['15.42', '54.82', '28927']
# ['13.02', '57.08', '28949']
# Euclidean Distance:  3.296604313532334
# Time Difference:  22
# Local Processing Fluency:  0.1498456506151061
#
#
# ['13.02', '57.08', '28949']
# ['13.02', '57.08', '28967']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['13.02', '57.08', '28967']
# ['13.02', '57.08', '28993']
# Euclidean Distance:  0.0
# Time Difference:  26
# Local Processing Fluency:  0.0
#
#
# ['13.02', '57.08', '28993']
# ['13.59', '81.72', '29034']
# Euclidean Distance:  24.646592056509554
# Time Difference:  41
# Local Processing Fluency:  0.6011363916221842
#
#
# ['13.59', '81.72', '29034']
# ['10.16', '63.76', '29057']
# Euclidean Distance:  18.284597343119156
# Time Difference:  23
# Local Processing Fluency:  0.7949824931790938
#
#
# ['10.16', '63.76', '29057']
# ['10.16', '63.76', '29075']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['10.16', '63.76', '29075']
# ['10.16', '63.76', '29095']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['10.16', '63.76', '29095']
# ['12.71', '70.53', '29119']
# Euclidean Distance:  7.234320977120109
# Time Difference:  24
# Local Processing Fluency:  0.30143004071333784
#
#
# ['12.71', '70.53', '29119']
# ['12.71', '70.53', '29137']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['12.71', '70.53', '29137']
# ['8.23', '60.37', '29160']
# Euclidean Distance:  11.10387319812326
# Time Difference:  23
# Local Processing Fluency:  0.4827770955705765
#
#
# ['8.23', '60.37', '29160']
# ['8.23', '60.37', '29180']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['8.23', '60.37', '29180']
# ['11.04', '66.86', '29203']
# Euclidean Distance:  7.072213232079475
# Time Difference:  23
# Local Processing Fluency:  0.3074875318295424
#
#
# ['11.04', '66.86', '29203']
# ['11.04', '66.86', '29226']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['11.04', '66.86', '29226']
# ['16.67', '56.89', '29248']
# Euclidean Distance:  11.44979475798584
# Time Difference:  22
# Local Processing Fluency:  0.5204452162720836
#
#
# ['16.67', '56.89', '29248']
# ['16.67', '56.89', '29266']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['16.67', '56.89', '29266']
# ['16.67', '56.89', '29284']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['16.67', '56.89', '29284']
# ['12.66', '60.28', '29308']
# Euclidean Distance:  5.250923728259631
# Time Difference:  24
# Local Processing Fluency:  0.2187884886774846
#
#
# ['12.66', '60.28', '29308']
# ['12.66', '60.28', '29327']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['12.66', '60.28', '29327']
# ['12.66', '60.28', '29346']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['12.66', '60.28', '29346']
# ['18.07', '66.3', '29369']
# Euclidean Distance:  8.09373214283744
# Time Difference:  23
# Local Processing Fluency:  0.3519013975146713
#
#
# ['18.07', '66.3', '29369']
# ['31.2', '30.28', '29388']
# Euclidean Distance:  38.338457193789104
# Time Difference:  19
# Local Processing Fluency:  2.017813536515216
#
#
# ['31.2', '30.28', '29388']
# ['11.25', '78.05', '29412']
# Euclidean Distance:  51.76847882640555
# Time Difference:  24
# Local Processing Fluency:  2.157019951100231
#
#
# ['11.25', '78.05', '29412']
# ['28.18', '77.86', '29431']
# Euclidean Distance:  16.931066121186817
# Time Difference:  19
# Local Processing Fluency:  0.8911087432203587
#
#
# ['28.18', '77.86', '29431']
# ['33.59', '72.69', '29452']
# Euclidean Distance:  7.483114324931837
# Time Difference:  21
# Local Processing Fluency:  0.35633877737770653
#
#
# ['33.59', '72.69', '29452']
# ['43.49', '93', '29469']
# Euclidean Distance:  22.59438204510139
# Time Difference:  17
# Local Processing Fluency:  1.32908129677067
#
#
# ['43.49', '93', '29469']
# ['43.49', '93', '29488']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['43.49', '93', '29488']
# ['43.39', '28.87', '29510']
# Euclidean Distance:  64.13007796658289
# Time Difference:  22
# Local Processing Fluency:  2.915003543935586
#
#
# ['43.39', '28.87', '29510']
# ['48.28', '35.45', '29528']
# Euclidean Distance:  8.19807904328813
# Time Difference:  18
# Local Processing Fluency:  0.4554488357382295
#
#
# ['48.28', '35.45', '29528']
# ['48.28', '35.45', '29547']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['48.28', '35.45', '29547']
# ['39.9', '15.33', '29571']
# Euclidean Distance:  21.79538483257408
# Time Difference:  24
# Local Processing Fluency:  0.9081410346905866
#
#
# ['39.9', '15.33', '29571']
# ['50.42', '5.83', '29589']
# Euclidean Distance:  14.174639325217418
# Time Difference:  18
# Local Processing Fluency:  0.7874799625120787
#
#
# ['50.42', '5.83', '29589']
# ['45.83', '0', '29612']
# Euclidean Distance:  7.4200404311566945
# Time Difference:  23
# Local Processing Fluency:  0.32261045352855194
#
#
# ['45.83', '0', '29612']
# ['53.49', '5.36', '29630']
# Euclidean Distance:  9.34907482053706
# Time Difference:  18
# Local Processing Fluency:  0.5193930455853922
#
#
# ['53.49', '5.36', '29630']
# ['45.94', '22.57', '29653']
# Euclidean Distance:  18.79325942991263
# Time Difference:  23
# Local Processing Fluency:  0.8170982360831579
#
#
# ['45.94', '22.57', '29653']
# ['48.02', '45.33', '29675']
# Euclidean Distance:  22.85484631320018
# Time Difference:  22
# Local Processing Fluency:  1.0388566506000083
#
#
# ['48.02', '45.33', '29675']
# ['52.76', '31.5', '29699']
# Euclidean Distance:  14.619729819664927
# Time Difference:  24
# Local Processing Fluency:  0.6091554091527053
#
#
# ['52.76', '31.5', '29699']
# ['52.76', '31.5', '29722']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['52.76', '31.5', '29722']
# ['44.58', '47.02', '29741']
# Euclidean Distance:  17.543739624150835
# Time Difference:  19
# Local Processing Fluency:  0.9233547170605703
#
#
# ['44.58', '47.02', '29741']
# ['40.42', '33.29', '29764']
# Euclidean Distance:  14.34637584897315
# Time Difference:  23
# Local Processing Fluency:  0.6237554716944848
#
#
# ['40.42', '33.29', '29764']
# ['40.42', '33.29', '29782']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['40.42', '33.29', '29782']
# ['41.15', '41.47', '29805']
# Euclidean Distance:  8.212508751897923
# Time Difference:  23
# Local Processing Fluency:  0.35706559790860537
#
#
# ['41.15', '41.47', '29805']
# ['41.15', '41.47', '29838']
# Euclidean Distance:  0.0
# Time Difference:  33
# Local Processing Fluency:  0.0
#
#
# ['41.15', '41.47', '29838']
# ['50.52', '39.03', '29861']
# Euclidean Distance:  9.682484185373093
# Time Difference:  23
# Local Processing Fluency:  0.420977573277091
#
#
# ['50.52', '39.03', '29861']
# ['50.52', '39.03', '29879']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['50.52', '39.03', '29879']
# ['52.86', '52.85', '29902']
# Euclidean Distance:  14.016704320203091
# Time Difference:  23
# Local Processing Fluency:  0.6094219269653518
#
#
# ['52.86', '52.85', '29902']
# ['52.86', '52.85', '29925']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['52.86', '52.85', '29925']
# ['46.67', '41', '29949']
# Euclidean Distance:  13.369315614495756
# Time Difference:  24
# Local Processing Fluency:  0.5570548172706565
#
#
# ['46.67', '41', '29949']
# ['46.67', '41', '29967']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['46.67', '41', '29967']
# ['46.67', '41', '29987']
# Euclidean Distance:  0.0
# Time Difference:  20
# Local Processing Fluency:  0.0
#
#
# ['46.67', '41', '29987']
# ['47.19', '47.11', '30010']
# Euclidean Distance:  6.132087735836791
# Time Difference:  23
# Local Processing Fluency:  0.2666125102537735
#
#
# ['47.19', '47.11', '30010']
# ['47.19', '47.11', '30028']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['47.19', '47.11', '30028']
# ['47.19', '47.11', '30047']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['47.19', '47.11', '30047']
# ['44.48', '47.77', '30071']
# Euclidean Distance:  2.7892113580723867
# Time Difference:  24
# Local Processing Fluency:  0.11621713991968279
#
#
# ['44.48', '47.77', '30071']
# ['44.48', '47.77', '30089']
# Euclidean Distance:  0.0
# Time Difference:  18
# Local Processing Fluency:  0.0
#
#
# ['44.48', '47.77', '30089']
# ['40.05', '57.27', '30111']
# Euclidean Distance:  10.482122876593271
# Time Difference:  22
# Local Processing Fluency:  0.4764601307542396
#
#
# ['40.05', '57.27', '30111']
# ['40.05', '57.27', '30130']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
#
#
# ['40.05', '57.27', '30130']
# ['41.35', '66.39', '30154']
# Euclidean Distance:  9.212187579505747
# Time Difference:  24
# Local Processing Fluency:  0.38384114914607276
#
#
# ['41.35', '66.39', '30154']
# ['41.35', '66.39', '30177']
# Euclidean Distance:  0.0
# Time Difference:  23
# Local Processing Fluency:  0.0
#
#
# ['41.35', '66.39', '30177']
# ['39.95', '81.25', '30200']
# Euclidean Distance:  14.925803160969261
# Time Difference:  23
# Local Processing Fluency:  0.6489479635204026
#
#
# ['39.95', '81.25', '30200']
# ['51.72', '59.62', '30219']
# Euclidean Distance:  24.62498324872527
# Time Difference:  19
# Local Processing Fluency:  1.296051749932909
#
#
# ['51.72', '59.62', '30219']
# ['51.72', '59.62', '30238']
# Euclidean Distance:  0.0
# Time Difference:  19
# Local Processing Fluency:  0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2dfdbae919d5> in <module>
#      44                 Inverse_PF_data.append(Inverse_PF)
#      45                 print('\n')
# ---> 46             if(len(PF_data)>0):
#      47                 average = Average_List(Inverse_PF_data)
#      48                 print('Average Processing Fluency for Test: ', average)
#
# NameError: name 'PF_data' is not defined
